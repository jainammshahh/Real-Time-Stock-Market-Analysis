# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
#pip install s3fs

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['100.25.12.242:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'N100', 'Date': '2020-11-19', 'Open': 1075.079956, 'High': 1079.890015, 'Low': 1073.170044, 'Close': 1077.550049, 'Adj Close': 1077.550049, 'Volume': 239233800.0, 'CloseUSD': 1314.61105978}
# {'Index': 'SSMI', 'Date': '2002-09-04', 'Open': 4873.299805, 'High': 5003.200195, 'Low': 4830.0, 'Close': 4960.0, 'Adj Close': 4960.0, 'Volume': 0.0, 'CloseUSD': 5505.6}
# {'Index': 'SSMI', 'Date': '1992-05-15', 'Open': 1944.5, 'High': 1944.5, 'Low': 1916.900024, 'Close': 1921.099976, 'Adj Close': 1921.099976, 'Volume': 0.0, 'CloseUSD': 2132.42097336}
# {'Index': 'HSI', 'Date': '2012-02-14', 'Open': 20845.24023, 'High': 20947.94922, 'Low': 20813.5293, 'Close': 20917.83008, 'Adj Close': 20917.83008, 'Volume': 1174512100.0, 'CloseUSD': 2719.3179104}
# {'Index': 'GDAXI', 'Date': '2018-04-17', 'Open': 12443.2002, 'High': 12614.25, 'Low': 12417.25977, 'Close': 12585.57031, 'Adj Close': 12585.57031, 'Volume': 85350700.0, 'CloseUSD': 15354.395778199998}
# {'Index': 'SSMI', 'Date': '1998-04-02', 'Open': 7614.299805, 'High': 7657.5, 'Low': 7583.399902, 'Close': 7638.799805, 'Adj Close': 7638.799805, 'Volume': 0.0, 'CloseUSD': 8479.067783550001}
# {'Index': 'NYA', 'Date': '1974-06-11', 'Open': 513.460022, 'High': 513.460022, 'Low': 513.460022, 'Close': 513.460022, 'Adj Close': 513.460022, 'Volume': 0.0, 'CloseUSD': 513.460022}
# {'Index': 'GSPTSE', 'Date': '2017-03-29', 'Open': 15585.5, 'High': 15661.59961, 'Low': 15545.0, 'Close': 15657.59961, 'Adj Close': 15657.59961, 'Volume': 18425600000.0, 'CloseUSD': 12995.8076763}
# {'Index': 'N225', 'Date': '2019-01-23', 'Open': 20453.43945, 'High': 20686.28906, 'Low': 20438.2207, 'Close': 20593.7207, 'Adj Close': 20593.7207, 'Volume': 0.0, 'CloseUSD': 205.93720700000003}
# {'Index': 'NYA', 'Date': '1994-11-18', 'Open': 2667.75, 'High': 2667.75, 'Low': 2667.75, 'Close': 2667.75, 'Adj Close': 2667.75, 'Volume': 0.0, 'CloseUSD': 2667.75}
# {'Index': 'IXIC', 'Date': '2018-11-12', 'Open': 7364.049805, 'High': 7371.089844, 'Low': 7193.77002, 'Close': 7200.870117, 'Adj Close': 7200.870117, 'Volume': 2289070000.0, 'CloseUSD': 7200.870117}
# {'Index': 'HSI', 'Date': '2017-06-13', 'Open': 25826.51953, 'High': 25883.2207, 'Low': 25722.63086, 'Close': 25852.09961, 'Adj Close': 25852.09961, 'Volume': 1316444700.0, 'CloseUSD': 3360.7729493}
# {'Index': 'IXIC', 'Date': '1985-02-14', 'Open': 289.100006, 'High': 289.299988, 'Low': 288.399994, 'Close': 288.399994, 'Adj Close': 288.399994, 'Volume': 124300000.0, 'CloseUSD': 288.399994}
# {'Index': 'SSMI', 'Date': '1992-07-13', 'Open': 1855.099976, 'High': 1855.099976, 'Low': 1839.900024, 'Close': 1841.5, 'Adj Close': 1841.5, 'Volume': 0.0, 'CloseUSD': 2044.0650000000005}
# {'Index': 'SSMI', 'Date': '1998-04-22', 'Open': 7369.0, 'High': 7430.700195, 'Low': 7250.200195, 'Close': 7308.899902, 'Adj Close': 7308.899902, 'Volume': 0.0, 'CloseUSD': 8112.878891220001}
# {'Index': 'N225', 'Date': '1980-06-24', 'Open': 6806.370117, 'High': 6806.370117, 'Low': 6806.370117, 'Close': 6806.370117, 'Adj Close': 6806.370117, 'Volume': 0.0, 'CloseUSD': 68.06370117}
# {'Index': 'NYA', 'Date': '1973-08-31', 'Open': 588.320007, 'High': 588.320007, 'Low': 588.320007, 'Close': 588.320007, 'Adj Close': 588.320007, 'Volume': 0.0, 'CloseUSD': 588.320007}
# {'Index': 'N225', 'Date': '2012-04-20', 'Open': 9574.990234, 'High': 9580.870117, 'Low': 9532.679688, 'Close': 9561.360352, 'Adj Close': 9561.360352, 'Volume': 109800000.0, 'CloseUSD': 95.61360352}
# {'Index': 'HSI', 'Date': '1996-03-12', 'Open': 10642.7002, 'High': 10737.09961, 'Low': 10565.40039, 'Close': 10602.5, 'Adj Close': 10602.5, 'Volume': 0.0, 'CloseUSD': 1378.325}
# {'Index': 'N100', 'Date': '2020-10-14', 'Open': 996.210022, 'High': 1000.02002, 'Low': 993.340027, 'Close': 995.890015, 'Adj Close': 995.890015, 'Volume': 194828600.0, 'CloseUSD': 1214.9858183}
# {'Index': 'N225', 'Date': '1995-10-12', 'Open': 17909.13086, 'High': 18051.60938, 'Low': 17840.9707, 'Close': 17971.40039, 'Adj Close': 17971.40039, 'Volume': 0.0, 'CloseUSD': 179.7140039}
# {'Index': 'GSPTSE', 'Date': '2018-08-20', 'Open': 16332.09961, 'High': 16370.90039, 'Low': 16317.40039, 'Close': 16331.0, 'Adj Close': 16331.0, 'Volume': 20875190000.0, 'CloseUSD': 13554.73}
# {'Index': 'NYA', 'Date': '2016-04-22', 'Open': 10464.2002, 'High': 10520.0, 'Low': 10464.2002, 'Close': 10511.0, 'Adj Close': 10511.0, 'Volume': 3790580000.0, 'CloseUSD': 10511.0}
# {'Index': 'N100', 'Date': '2005-01-21', 'Open': 660.47998, 'High': 664.0, 'Low': 660.47998, 'Close': 663.659973, 'Adj Close': 663.659973, 'Volume': 0.0, 'CloseUSD': 809.66516706}
# {'Index': 'HSI', 'Date': '1992-03-02', 'Open': 4930.600098, 'High': 4987.0, 'Low': 4905.799805, 'Close': 4952.200195, 'Adj Close': 4952.200195, 'Volume': 0.0, 'CloseUSD': 643.78602535}
# {'Index': 'IXIC', 'Date': '2013-05-29', 'Open': 3471.669922, 'High': 3479.530029, 'Low': 3450.399902, 'Close': 3467.52002, 'Adj Close': 3467.52002, 'Volume': 1794650000.0, 'CloseUSD': 3467.52002}
# {'Index': 'NYA', 'Date': '2015-07-27', 'Open': 10688.86035, 'High': 10698.53027, 'Low': 10636.26953, 'Close': 10656.61035, 'Adj Close': 10656.61035, 'Volume': 3836750000.0, 'CloseUSD': 10656.61035}
# {'Index': 'TWII', 'Date': '2011-08-31', 'Open': 7665.220215, 'High': 7741.359863, 'Low': 7602.680176, 'Close': 7741.359863, 'Adj Close': 7741.331055, 'Volume': 2482400.0, 'CloseUSD': 309.65439452}
# {'Index': 'IXIC', 'Date': '1992-10-01', 'Open': 581.080017, 'High': 582.47998, 'Low': 577.830017, 'Close': 578.330017, 'Adj Close': 578.330017, 'Volume': 185130000.0, 'CloseUSD': 578.330017}
# {'Index': 'GDAXI', 'Date': '2011-02-17', 'Open': 7429.0, 'High': 7434.930176, 'Low': 7364.040039, 'Close': 7405.509766, 'Adj Close': 7405.509766, 'Volume': 112233100.0, 'CloseUSD': 9034.72191452}
# {'Index': '000001.SS', 'Date': '2000-08-10', 'Open': 2065.304932, 'High': 2067.745117, 'Low': 2053.861084, 'Close': 2065.943115, 'Adj Close': 2065.943115, 'Volume': 0.0, 'CloseUSD': 330.5508984}
# {'Index': 'GDAXI', 'Date': '1998-03-27', 'Open': 5020.189941, 'High': 5100.799805, 'Low': 5008.569824, 'Close': 5066.899902, 'Adj Close': 5066.899902, 'Volume': 0.0, 'CloseUSD': 6181.61788044}
# {'Index': 'N100', 'Date': '2017-10-31', 'Open': 1065.050049, 'High': 1069.73999, 'Low': 1064.560059, 'Close': 1068.22998, 'Adj Close': 1068.22998, 'Volume': 165668900.0, 'CloseUSD': 1303.2405756}
# {'Index': 'GSPTSE', 'Date': '2008-07-16', 'Open': 13356.29981, 'High': 13514.7002, 'Low': 13167.29981, 'Close': 13503.79981, 'Adj Close': 13503.79981, 'Volume': 27221410000.0, 'CloseUSD': 11208.1538423}
# {'Index': 'GDAXI', 'Date': '2011-11-10', 'Open': 5732.319824, 'High': 5934.310059, 'Low': 5721.970215, 'Close': 5867.810059, 'Adj Close': 5867.810059, 'Volume': 201635400.0, 'CloseUSD': 7158.7282719800005}
# {'Index': 'IXIC', 'Date': '2018-04-09', 'Open': 6971.450195, 'High': 7074.950195, 'Low': 6944.959961, 'Close': 6950.339844, 'Adj Close': 6950.339844, 'Volume': 2080900000.0, 'CloseUSD': 6950.339844}
# {'Index': 'GDAXI', 'Date': '2012-05-31', 'Open': 6297.680176, 'High': 6322.689941, 'Low': 6208.089844, 'Close': 6264.379883, 'Adj Close': 6264.379883, 'Volume': 147218300.0, 'CloseUSD': 7642.54345726}
# {'Index': 'TWII', 'Date': '2020-08-17', 'Open': 12813.94043, 'High': 12956.11035, 'Low': 12800.69043, 'Close': 12956.11035, 'Adj Close': 12956.11035, 'Volume': 4310300.0, 'CloseUSD': 518.244414}
# {'Index': 'NSEI', 'Date': '2012-05-31', 'Open': 4896.100098, 'High': 4924.25, 'Low': 4894.450195, 'Close': 4924.25, 'Adj Close': 4924.25, 'Volume': 0.0, 'CloseUSD': 49.2425}
# {'Index': 'N225', 'Date': '1977-09-28', 'Open': 5185.0, 'High': 5185.0, 'Low': 5185.0, 'Close': 5185.0, 'Adj Close': 5185.0, 'Volume': 0.0, 'CloseUSD': 51.85}
# {'Index': 'GSPTSE', 'Date': '2001-12-13', 'Open': 7518.600098, 'High': 7532.700195, 'Low': 7446.100098, 'Close': 7451.200195, 'Adj Close': 7451.200195, 'Volume': 10255880000.0, 'CloseUSD': 6184.49616185}
# {'Index': 'GSPTSE', 'Date': '2004-07-30', 'Open': 8443.099609, 'High': 8493.099609, 'Low': 8431.099609, 'Close': 8458.099609, 'Adj Close': 8458.099609, 'Volume': 7372440000.0, 'CloseUSD': 7020.2226754700005}
# {'Index': '399001.SZ', 'Date': '1999-06-09', 'Open': 3441.830078, 'High': 3496.399902, 'Low': 3399.929932, 'Close': 3481.909912, 'Adj Close': 3481.87085, 'Volume': 0.0, 'CloseUSD': 557.1055859200001}
# {'Index': 'IXIC', 'Date': '1972-09-14', 'Open': 127.580002, 'High': 127.580002, 'Low': 127.580002, 'Close': 127.580002, 'Adj Close': 127.580002, 'Volume': 0.0, 'CloseUSD': 127.580002}
# {'Index': 'J203.JO', 'Date': '2015-09-23', 'Open': 49853.08984, 'High': 50458.76953, 'Low': 49714.08984, 'Close': 50381.62891, 'Adj Close': 50381.62891, 'Volume': 0.0, 'CloseUSD': 3526.7140237000003}
# {'Index': 'NYA', 'Date': '2018-07-13', 'Open': 12744.79981, 'High': 12783.24023, 'Low': 12727.75977, 'Close': 12769.5, 'Adj Close': 12769.5, 'Volume': 2614000000.0, 'CloseUSD': 12769.5}
# {'Index': '000001.SS', 'Date': '2001-02-28', 'Open': 1964.355957, 'High': 1965.020996, 'Low': 1950.93103, 'Close': 1959.180054, 'Adj Close': 1959.180054, 'Volume': 0.0, 'CloseUSD': 313.46880864}
# {'Index': 'GSPTSE', 'Date': '2005-02-09', 'Open': 9366.5, 'High': 9402.599609, 'Low': 9362.799805, 'Close': 9402.599609, 'Adj Close': 9402.599609, 'Volume': 13049490000.0, 'CloseUSD': 7804.15767547}
# {'Index': 'N225', 'Date': '1981-08-25', 'Open': 7817.220215, 'High': 7817.220215, 'Low': 7817.220215, 'Close': 7817.220215, 'Adj Close': 7817.220215, 'Volume': 0.0, 'CloseUSD': 78.17220215}
# {'Index': 'N225', 'Date': '1979-09-13', 'Open': 6447.870117, 'High': 6447.870117, 'Low': 6447.870117, 'Close': 6447.870117, 'Adj Close': 6447.870117, 'Volume': 0.0, 'CloseUSD': 64.47870117000001}
# {'Index': 'N225', 'Date': '1969-07-01', 'Open': 1969.670044, 'High': 1969.670044, 'Low': 1969.670044, 'Close': 1969.670044, 'Adj Close': 1969.670044, 'Volume': 0.0, 'CloseUSD': 19.69670044}
# {'Index': 'SSMI', 'Date': '1991-02-01', 'Open': 1434.699951, 'High': 1453.199951, 'Low': 1428.699951, 'Close': 1448.099976, 'Adj Close': 1448.099976, 'Volume': 0.0, 'CloseUSD': 1607.39097336}
# {'Index': 'HSI', 'Date': '2006-07-26', 'Open': 16584.49023, 'High': 16623.46094, 'Low': 16566.39063, 'Close': 16617.24023, 'Adj Close': 16617.24023, 'Volume': 235033400.0, 'CloseUSD': 2160.2412299}
# {'Index': 'HSI', 'Date': '2018-11-26', 'Open': 26099.34961, 'High': 26413.75977, 'Low': 26031.90039, 'Close': 26376.17969, 'Adj Close': 26376.17969, 'Volume': 1611982200.0, 'CloseUSD': 3428.9033597}
# {'Index': 'N225', 'Date': '2019-03-25', 'Open': 21267.41016, 'High': 21275.42969, 'Low': 20911.57031, 'Close': 20977.10938, 'Adj Close': 20977.10938, 'Volume': 77700000.0, 'CloseUSD': 209.7710938}
# {'Index': 'TWII', 'Date': '2002-05-24', 'Open': 5588.589844, 'High': 5718.740234, 'Low': 5586.930176, 'Close': 5706.399902, 'Adj Close': 5706.378906, 'Volume': 0.0, 'CloseUSD': 228.25599608}
# {'Index': 'GDAXI', 'Date': '1990-01-16', 'Open': 1806.099976, 'High': 1806.099976, 'Low': 1806.099976, 'Close': 1806.099976, 'Adj Close': 1806.099976, 'Volume': 0.0, 'CloseUSD': 2203.44197072}
# {'Index': 'HSI', 'Date': '2000-01-11', 'Open': 15981.12988, 'High': 16196.08984, 'Low': 15736.16992, 'Close': 15862.09961, 'Adj Close': 15862.09961, 'Volume': 0.0, 'CloseUSD': 2062.0729493}
# {'Index': '000001.SS', 'Date': '2020-12-02', 'Open': 3453.518066, 'High': 3465.729004, 'Low': 3435.871094, 'Close': 3449.381104, 'Adj Close': 3449.381104, 'Volume': 312800.0, 'CloseUSD': 551.9009766400001}
# {'Index': 'IXIC', 'Date': '2011-06-10', 'Open': 2675.100098, 'High': 2676.719971, 'Low': 2641.639893, 'Close': 2643.72998, 'Adj Close': 2643.72998, 'Volume': 1972000000.0, 'CloseUSD': 2643.72998}
# {'Index': 'TWII', 'Date': '2021-04-26', 'Open': 17378.35938, 'High': 17572.28906, 'Low': 17378.35938, 'Close': 17572.28906, 'Adj Close': 17572.28906, 'Volume': 9298000.0, 'CloseUSD': 702.8915624}
# {'Index': 'NYA', 'Date': '1992-12-23', 'Open': 2548.27002, 'High': 2548.27002, 'Low': 2548.27002, 'Close': 2548.27002, 'Adj Close': 2548.27002, 'Volume': 0.0, 'CloseUSD': 2548.27002}
# {'Index': 'NYA', 'Date': '2019-12-06', 'Open': 13515.48047, 'High': 13612.05957, 'Low': 13515.48047, 'Close': 13588.29004, 'Adj Close': 13588.29004, 'Volume': 3479480000.0, 'CloseUSD': 13588.29004}
# {'Index': 'N100', 'Date': '2000-04-12', 'Open': 1018.280029, 'High': 1018.280029, 'Low': 1018.280029, 'Close': 1018.280029, 'Adj Close': 1018.280029, 'Volume': 0.0, 'CloseUSD': 1242.30163538}
# {'Index': 'NYA', 'Date': '1987-08-04', 'Open': 1875.670044, 'High': 1875.670044, 'Low': 1875.670044, 'Close': 1875.670044, 'Adj Close': 1875.670044, 'Volume': 0.0, 'CloseUSD': 1875.670044}
# {'Index': 'SSMI', 'Date': '2015-12-11', 'Open': 8605.969727, 'High': 8641.450195, 'Low': 8477.839844, 'Close': 8502.05957, 'Adj Close': 8502.05957, 'Volume': 59181400.0, 'CloseUSD': 9437.2861227}
# {'Index': 'NYA', 'Date': '2006-04-20', 'Open': 8431.219727, 'High': 8458.830078, 'Low': 8390.639648, 'Close': 8422.129883, 'Adj Close': 8422.129883, 'Volume': 2512920000.0, 'CloseUSD': 8422.129883}
# {'Index': 'HSI', 'Date': '2008-11-24', 'Open': 12239.49023, 'High': 12707.23047, 'Low': 12239.49023, 'Close': 12457.94043, 'Adj Close': 12457.94043, 'Volume': 1769147200.0, 'CloseUSD': 1619.5322559}
# {'Index': 'IXIC', 'Date': '1975-02-27', 'Open': 72.529999, 'High': 72.529999, 'Low': 72.529999, 'Close': 72.529999, 'Adj Close': 72.529999, 'Volume': 0.0, 'CloseUSD': 72.529999}
# {'Index': 'N225', 'Date': '1994-03-24', 'Open': 19970.19922, 'High': 20075.81055, 'Low': 19870.08984, 'Close': 20037.90039, 'Adj Close': 20037.90039, 'Volume': 0.0, 'CloseUSD': 200.3790039}
# {'Index': '000001.SS', 'Date': '2006-05-16', 'Open': 1658.692017, 'High': 1678.598999, 'Low': 1604.784058, 'Close': 1613.250977, 'Adj Close': 1613.250977, 'Volume': 88200.0, 'CloseUSD': 258.12015632}
# {'Index': '399001.SZ', 'Date': '2016-05-03', 'Open': 10144.15039, 'High': 10441.91992, 'Low': 10105.79981, 'Close': 10441.91992, 'Adj Close': 10441.80273, 'Volume': 968500.0, 'CloseUSD': 1670.7071872}
# {'Index': 'GSPTSE', 'Date': '2021-02-08', 'Open': 18236.40039, 'High': 18333.80078, 'Low': 18236.40039, 'Close': 18330.30078, 'Adj Close': 18330.30078, 'Volume': 30459530000.0, 'CloseUSD': 15214.1496474}
# {'Index': 'NYA', 'Date': '1974-08-19', 'Open': 414.070007, 'High': 414.070007, 'Low': 414.070007, 'Close': 414.070007, 'Adj Close': 414.070007, 'Volume': 0.0, 'CloseUSD': 414.070007}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/m7/fd_p4dd55_xf1f1ttd8mbdmr0000gn/T/ipykernel_4303/2861557713.py in <module>
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# ~/opt/anaconda3/lib/python3.9/selectors.py in select(self, timeout)
#     560             ready = []
#     561             try:
# --> 562                 kev_list = self._selector.control(None, max_ev, timeout)
#     563             except InterruptedError:
#     564                 return ready
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    print(count)
    print(i.value)
# Out:
# 0
# {'hello': 'world'}
# 1
# {'hello': 'world'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/m7/fd_p4dd55_xf1f1ttd8mbdmr0000gn/T/ipykernel_4303/2395472651.py in <module>
# ----> 1 for count, i in enumerate(consumer):
#       2     print(count)
#       3     print(i.value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# ~/opt/anaconda3/lib/python3.9/selectors.py in select(self, timeout)
#     560             ready = []
#     561             try:
# --> 562                 kev_list = self._selector.control(None, max_ev, timeout)
#     563             except InterruptedError:
#     564                 return ready
#
# KeyboardInterrupt:

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-project/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/m7/fd_p4dd55_xf1f1ttd8mbdmr0000gn/T/ipykernel_4303/2376214929.py in <module>
#       1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-project/stock_market_{}.json".format(count), 'w') as file:
# ----> 3         json.dump(i.value, file)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/spec.py in close(self)
#    1784         else:
#    1785             if not self.forced:
# -> 1786                 self.flush(force=True)
#    1787
#    1788             if self.fs is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/spec.py in flush(self, force)
#    1655                 raise
#    1656
# -> 1657         if self._upload_chunk(final=force) is not False:
#    1658             self.offset += self.buffer.seek(0, 2)
#    1659             self.buffer = io.BytesIO()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3fs/core.py in _upload_chunk(self, final)
#    2213
#    2214         if self.autocommit and final:
# -> 2215             self.commit()
#    2216         return not final
#    2217
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3fs/core.py in commit(self)
#    2228                 self.buffer.seek(0)
#    2229                 data = self.buffer.read()
# -> 2230                 write_result = self._call_s3(
#    2231                     "put_object",
#    2232                     Key=self.key,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3fs/core.py in _call_s3(self, method, *kwarglist, **kwargs)
#    2080
#    2081     def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2082         return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#    2083
#    2084     def _initiate_upload(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#     113     def wrapper(*args, **kwargs):
#     114         self = obj or args[0]
# --> 115         return sync(self.loop, func, *args, **kwargs)
#     116
#     117     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      86     while True:
#      87         # this loops allows thread to get interrupted
# ---> 88         if event.wait(1):
#      89             break
#      90         if timeout is not None:
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
